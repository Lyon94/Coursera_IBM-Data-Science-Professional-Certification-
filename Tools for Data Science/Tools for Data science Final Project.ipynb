# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Abdullateef Abass**

# %% [markdown]
# I'm a chemical engineer.

# %% [markdown]
# *I am passionate about Data Science because I believe I'm highly curious and love to go deep down to the root causes of issues to get it solved.*

# %% [markdown]
# ### This code will carry out basic mathematics computation and print the answer.

# %%
def computeAge(userDOB):
    currentYear = 2021
    userAge = currentYear - userDOB
    
    return userAge

print(computeAge(1994))
# Out:
# 27

# %% [markdown]
# The user age;
# ***
#
# calculated from the computeAge function is;
#
#
# between:
# 1. 25
# 2. 26
# 3. 27
#
# or between:
# * 25
# * 26
# * 27
#
# > Conclusively, the user's age is 27.

# %% [markdown]
# Check out the notbook [here](https://eu-gb.dataplatform.cloud.ibm.com/analytics/notebooks/v2/0270b649-78f2-459d-979f-1fa43fd8053e/view?access_token=e9d9c45a634e1300c662c100915b9992cb9b0898f0dd056fe6af3baa5d68f0ac).
